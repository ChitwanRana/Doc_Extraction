# %%
import pandas as pd

# %%
df=pd.read_csv("extracted_data.csv")

# %%
df
# Out:
#          Dataset  # of keys or categories # of examples (train/dev/test)  \
# 0       IIT-CDIP                      NaN                        11M/0/0
# 1          FUNSD                      4.0                       149/0/50
# 2           CORD                     30.0                    800/100/100
# 3          SROIE                      4.0                      626/0/347
# 4   Kleister-NDA                      4.0                     254/83/203
# 5       RVL-CDIP                     16.0                     320K/4K/4K
# 6         DocVQA                      NaN                      39K/5K/5K
# 7            NaN                      NaN                            NaN
# 8            NaN                      NaN                            NaN
# 9            NaN                      NaN                            NaN
# 10           NaN                      NaN                            NaN
# 11           NaN                      NaN                            NaN
# ...
